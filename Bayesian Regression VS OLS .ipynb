# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
import scipy
import pymc3 as pm

# %%
exercise = pd.read_csv(r"C:\Users\vishal\Desktop\exercise.csv")
calories = pd.read_csv(r'C:\Users\vishal\Desktop\calories.csv')
df = pd.merge(exercise, calories, on = 'User_ID')
df = df[df['Calories'] < 300]
df = df.reset_index()
df['Intercept'] = 1
df.head()
# Out:
#    index   User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  \
# 0      0  14733363    male   68   190.0    94.0      29.0       105.0
# 1      1  14861698  female   20   166.0    60.0      14.0        94.0
# 2      2  11179863    male   69   179.0    79.0       5.0        88.0
# 3      3  16180408  female   34   179.0    71.0      13.0       100.0
# 4      4  17771927  female   27   154.0    58.0      10.0        81.0
#
#    Body_Temp  Calories  Intercept
# 0       40.8     231.0          1
# 1       40.3      66.0          1
# 2       38.7      26.0          1
# 3       40.5      71.0          1
# 4       39.8      35.0          1

# %%
plt.figure(figsize=(8, 8))

plt.plot(df['Duration'], df['Calories'], 'bo');
plt.xlabel('Duration (min)', size = 18); plt.ylabel('Calories', size = 18); 
plt.title('Calories burned vs Duration of Exercise', size = 20);

# %%
X = df.loc[:, ['Intercept', 'Duration']]
y = df.loc[:, 'Calories']

# %%
col_names = California_housing.columns

# %%
def linear_regression(X, y):
    # Equation for linear regression coefficients
    beta = np.matmul(np.matmul(np.linalg.inv(np.matmul(X.T, X)), X.T), y)
    return beta

# %%
by_hand_coefs = linear_regression(X, y)
print('Intercept calculated by hand:', by_hand_coefs[0])
print('Slope calculated by hand: ', by_hand_coefs[1])
# Out:
# Intercept calculated by hand: -21.828102526050834
# Slope calculated by hand:  7.1697833495878545
# C:\Users\vishal\AppData\Local\Temp\ipykernel_13256\3053671558.py:3: FutureWarning: Calling a ufunc on non-aligned DataFrames (or DataFrame/Series combination). Currently, the indices are ignored and the result takes the index/columns of the first DataFrame. In the future , the DataFrames/Series will be aligned before applying the ufunc.
# Convert one of the arguments to a NumPy array (eg 'ufunc(df1, np.asarray(df2)') to keep the current behaviour, or align manually (eg 'df1, df2 = df1.align(df2)') before passing to the ufunc to obtain the future behaviour and silence this warning.
#   beta = np.matmul(np.matmul(np.linalg.inv(np.matmul(X.T, X)), X.T), y)

# %%
xs = np.linspace(4, 31, 1000)
ys = by_hand_coefs[0] + by_hand_coefs[1] * xs

plt.figure(figsize=(8, 8))
plt.plot(df['Duration'], df['Calories'], 'bo', label = 'observations', alpha = 0.8);
plt.xlabel('Duration (min)', size = 18); plt.ylabel('Calories', size = 18); 
plt.plot(xs, ys, 'r--', label = 'OLS Fit', linewidth = 3)
plt.legend(prop={'size': 16})
plt.title('Calories burned vs Duration of Exercise', size = 20);

# %%
print('Exercising for 15.5 minutes will burn an estimated {:.2f} calories.'.format(
    by_hand_coefs[0] + by_hand_coefs[1] * 15.5))
# Out:
# Exercising for 15.5 minutes will burn an estimated 89.30 calories.

# %%
# !pip install pymc3
# Out:
# Requirement already satisfied: pymc3 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (3.11.5)
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\vishal\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: dill in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from pymc3) (0.3.4)
# Requirement already satisfied: cachetools>=4.2.1 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from pymc3) (5.0.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from pymc3) (4.1.1)
# Requirement already satisfied: semver>=2.13.0 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from pymc3) (2.13.0)
# Requirement already satisfied: fastprogress>=0.2.0 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from pymc3) (1.0.2)
# Requirement already satisfied: deprecat in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from pymc3) (2.1.1)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from pymc3) (1.4.1)
# Requirement already satisfied: arviz>=0.11.0 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from pymc3) (0.12.0)
# Requirement already satisfied: theano-pymc==1.1.2 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from pymc3) (1.1.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from pymc3) (0.5.2)
# Requirement already satisfied: numpy<1.22.2,>=1.15.0 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from pymc3) (1.22.1)
# Requirement already satisfied: scipy<1.8.0,>=1.7.3 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from pymc3) (1.7.3)
# Requirement already satisfied: filelock in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from theano-pymc==1.1.2->pymc3) (3.6.0)
# Requirement already satisfied: setuptools>=38.4 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from arviz>=0.11.0->pymc3) (58.1.0)
# Requirement already satisfied: xarray>=0.16.1 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from arviz>=0.11.0->pymc3) (2022.3.0)
# Requirement already satisfied: matplotlib>=3.0 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from arviz>=0.11.0->pymc3) (3.5.1)
# Requirement already satisfied: packaging in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from arviz>=0.11.0->pymc3) (21.3)
# Requirement already satisfied: netcdf4 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from arviz>=0.11.0->pymc3) (1.5.8)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (3.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (1.4.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (4.31.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.24.0->pymc3) (2022.1)
# Requirement already satisfied: six in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from patsy>=0.5.1->pymc3) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from deprecat->pymc3) (1.14.0)
# Requirement already satisfied: cftime in c:\users\vishal\appdata\local\programs\python\python39\lib\site-packages (from netcdf4->arviz>=0.11.0->pymc3) (1.6.0)
